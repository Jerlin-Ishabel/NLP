# %% [markdown]
# # 1.Simple Frequency Distribution

# %%
import nltk
from nltk.tokenize import TreebankWordTokenizer
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
# Initialize tokenizer
tokenizer=TreebankWordTokenizer()

# Sample text
text="Natural Language Processing(NLP) with python is fun and educational. python simplifies NLP tasks."

# Tokenize the text
tokens=tokenizer.tokenize(text)

# Print tokens
print("Tokens:",tokens)

#Frequency Distribution
fdist=FreqDist(tokens)

# Print frequencies
print("\n word Frequency Distribution:")
for word,freq in fdist.items():
      print(f"{word}:{freq}")
        
# Plot frequency distribution        
fdist.plot(title='simple frequency Distribution plot')
plt.show()
# Out:
# Tokens: ['Natural', 'Language', 'Processing', '(', 'NLP', ')', 'with', 'python', 'is', 'fun', 'and', 'educational.', 'python', 'simplifies', 'NLP', 'tasks', '.']
#
#  word Frequency Distribution:
# Natural:1
# Language:1
# Processing:1
# (:1
# NLP:2
# ):1
# with:1
# python:2
# is:1
# fun:1
# and:1
# educational.:1
# simplifies:1
# tasks:1
# .:1

# %%
plt.hist(fdist.values(), bins=2, edgecolor='black') 
plt.title('Simple Word Frequency Histogram')
plt.xlabel('Word Frequency')
plt.ylabel('Frequency Count')
plt.show()
